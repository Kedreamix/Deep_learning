# %% [markdown]
# # 1.导入所需要的库

# %%
# 导入所需要的库
from __future__ import print_function

import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.optim import lr_scheduler

# %% [markdown]
# # 2.CIFAR10数据集的预处理

# %%
# 超参数
lr = 1e-2
momentum = 0.9
weight_decay = 5e-4
nepochs = 10
Batch_size = 128

# %%
# 数据增强
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # 数据增广
    transforms.RandomHorizontalFlip(),  # 数据增广
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),  # 数据归一化
])
# transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],std=[0.2471, 0.2435, 0.2616]),#数据归一化

# %% [markdown]
# # download the CIFAR10 by torchvision, trainset is a torchvision.datasets object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# download the CIFAR10 by torchvision, trainset is a torchvision.datasets object
# transform is performed while obtaining the dataset
# the ./dataset directory is automatically created, and once dowloaded, this code can sense it and will not
# download it again
train_set = torchvision.datasets.CIFAR10('./data', train=True, 
                                         download=True, transform=transform)
test_set = torchvision.datasets.CIFAR10('./data', train=False, 
                                        download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=Batch_size, 
                                           shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=Batch_size, 
                                          shuffle=False, num_workers=4)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def get_loader(train_set,batch_size=128):
    loader = torch.utils.data.DataLoader(train_set,batch_size = batch_size,
                       num_workers=2,shuffle=True)
    return loader

# %%
def get_train_split_data( train_set, train_split = 0.8):
    num_train = len(train_set)
    indices = list(range(num_train))
    split = int(num_train * train_split)
    train_idx, val_idx = indices[:split], indices[split:]
    train_dataset = torch.utils.data.Subset(train_set,train_idx)
    return train_dataset

# %%
train_split_loader = []
train_splits = [0.01,0.1,0.5,0.8,1]
for train_split in train_splits:
    train_split_dataset = get_train_split_data(train_set,train_split)
    train_split_loader.append(get_loader(train_split_dataset,Batch_size))

# %%
for loader in train_split_loader:
    print(len(loader))
# Out:
# 4
# 40
# 196
# 313
# 391

# %% [markdown]
# # Image displaying

# %%
# Image displaying
import matplotlib.pyplot as plt
import numpy as np

def imshow(img):
    # normalizing
    img = img / 2 + 0.5 # imgs are already noramlized during Transforming in data prepration
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    # plt.show()

image_iter = iter(train_loader)
images, labels = image_iter.next()
imshow(torchvision.utils.make_grid(images[:4]))

# %%
fig = plt.figure(figsize=(25 , 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 10 , idx + 1, xticks =[], yticks = []) # 2 行 10 列
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

plt.show()

# %%
fig = plt.figure(figsize=(50 , 10))
imshow(torchvision.utils.make_grid(images[:64]))

# %% [markdown]
# # 测试是否能用GPU

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# # 构建VGG模型

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class VGG(nn.Module):
    
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        self.classifier = nn.Sequential(
            nn.Linear(512,512),
            nn.ReLU(True),
            nn.Dropout(0.2),
            nn.Linear(512,512),
            nn.ReLU(True),
            nn.Dropout(0.2),
            nn.Linear(512,10),
        )
#         self.classifier = nn.Linear(512,10)

        self._initialize_weight()
        
    def forward(self, x):
        out = self.features(x)
        # 在进入
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out
    
    # make layers
    def _make_layers(self, cfg):
        layers = []
        in_channels = 3 # RGB 初始通道为3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)] # kernel_size 为 2 x 2,然后步长为2
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1), # 都是(3.3)的卷积核
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]  # RelU
                in_channels = x  # 重定义通道
#         layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)
    
    # 初始化参数
    def _initialize_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # xavier is used in VGG's paper
                nn.init.xavier_normal_(m.weight.data)
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
net = VGG('VGG16').to(device)
print(net)
if device == 'cuda':
    net = nn.DataParallel(net)
    # 当计算图不会改变的时候（每次输入形状相同，模型不改变）的情况下可以提高性能，反之则降低性能
    torch.backends.cudnn.benchmark = True
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
x = torch.randn(2,3,32,32).to(device)
y = net(x)
print(y.shape)
# Out:
# torch.Size([2, 10])

# %% [markdown]
# # Training

# %%
# 定义训练的辅助函数
def eval(model, loss_func, dataloader):
    model.eval()
    loss,accuracy = 0,0
    
    # torch.no_grad不需要计算梯度
    with torch.no_grad():
        for batch_x, batch_y in dataloader:
            batch_x,batch_y = batch_x.to(device), batch_y.to(device)
            outputs = model(batch_x) 
            error = loss_func(outputs,batch_y) # 计算误差
            loss += error.item() 
            
            probs, pred_y = outputs.data.max(dim=1) # 得到概率
            accuracy += (pred_y==batch_y.data).float().sum()/batch_y.size(0) # 准确率
    loss /= len(dataloader)
    accuracy = accuracy*100.0 / len(dataloader)
    return loss, accuracy

def train_epoch(model, loss_func, optimizer, dataloader):
    model.train()
    for batch_x, batch_y in dataloader:
        batch_x,batch_y = batch_x.to(device), batch_y.to(device)
        optimizer.zero_grad() #将参数的grad值初始化为0
        outputs = model(batch_x)
        error = loss_func(outputs, batch_y)
        # 清理内存
        if hasattr(torch.cuda, 'empty_cache'):
            torch.cuda.empty_cache()
        error.backward()  # 反向传播
        # 单次优化
        optimizer.step()

# %%
# # Trainin
# def train(epoch):
#     print('\n Epoch: %d' % (epoch + 1))
#     net.train()
#     train_loss = 0
#     correct = 0
#     total = 0
#     for batch_idx, (inputs, targrts) in enumerate(train_loader):
#         inputs , targrts = inputs.to(device) , targrts.to(device)
        
#         optimizer.zero_grad()
#         outputs = net(inputs)
#         # 得到损失
#         loss= criterion(outputs, targrts)
#         # 清理内存
#         if hasattr(torch.cuda, 'empty_cache'):
#             torch.cuda.empty_cache()

#         # 反向传播
#         loss.backward()
#         # 单次优化
#         optimizer.step()
#         # 得到损失
#         train_loss += loss.item()
#         _, predicted = outputs.max(1)
#         total += targrts.size(0)
#         correct += predicted.eq(targrts).sum().item()
#         if batch_idx % 100 == 99:
#             print('[%d, %5d] loss: %.5f |  Acc:%3f%% (%d/%d)'%
#                  (epoch + 1, batch_idx + 1, train_loss / 2000, 100.*correct/total, correct, total))
#             train_loss = 0.0
#             total = 0
#             correct = 0

# %%
load_history = False
# load_history = True
if load_history:
    learn_history={'train_loss':[],'train_acc':[],'test_loss':[],'test_acc':[],'lr':[]}
    f = open('history.txt','r')
    lines = f.readlines()
    for line in lines:
        line = line.replace('\n','')
        line = line.split(' ')
        learn_history['train_loss'].append(float(line[0]))
        learn_history['test_loss'].append(float(line[1]))
        learn_history['train_acc'].append(float(line[2]))
        learn_history['test_acc'].append(float(line[3]))
        learn_history['lr'].append(float(line[4]))
    print('load learning history successfully')
else:
    learn_history={'train_loss':[],'train_acc':[],'test_loss':[],'test_acc':[],'lr':[]}

# %%
lr = 1e-2
momentum = 0.9
weight_decay = 5e-4
nepochs = 100
# 定义损失函数为交叉熵损失
criterion = nn.CrossEntropyLoss()
# 优化函数
optimizer = optim.SGD(net.parameters(), lr = lr ,momentum= momentum, weight_decay=weight_decay, nesterov=True)
# optimizer = optim.Adam(net.parameters(),lr = lr,weight_decay=weight_decay)
# scheduler = lr_scheduler.MultiStepLR(optimizer,milestones=[5,10,15] , gamma=0.1 ) # 根据指定的milestones 进行学习率的调整
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.3,verbose=True,patience = 5,min_lr = 0.000001) # 动态更新学习率
# scheduler = lr_scheduler.StepLR(optimizer, gamma=0.1 ,step_size = 20) 
# opt = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9, weight_decay=1e-4, nesterov=True)
#   lr_scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size=50, gamma=0.1)

# %%
# # 超参数设置2
# lr = 1e-2
# momentum = 0.9
# weight_decay = 5e-4
# nepochs = 200
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(net.parameters(),lr = lr,weight_decay=weight_decay)
# # 动态更新学习率
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5,verbose=True,patience = 5,min_lr = 0.000001) # 动态更新学习率

# %%
load_model = False
# load_model = True
if load_model:
    checkpoint = torch.load('./checkpoint/vgg.ckpt')
    net.load_state_dict(checkpoint['net'])
    start_epoch = checkpoint['epoch']
else:
    start_epoch = 0
print('start_epoch: %s' % start_epoch)
# Out:
# start_epoch: 0

# %%
for epoch in range(nepochs):
    # 训练开始时间
    since = time.time()
#     train_epoch(net, criterion, optimizer, train_loader)
    train_epoch(net,criterion,optimizer,train_split_loader[0])
#     scheduler.step(loss, epoch=epoch)
    # 每训练5轮输出一次结果
#     if (epoch)%5 == 0:
    tr_loss, tr_acc = eval(net, criterion, train_split_loader[0])
    te_loss, te_acc = eval(net, criterion, test_loader)
    learn_history['train_loss'].append(tr_loss)
    learn_history['train_acc'].append(tr_acc)
    learn_history['test_loss'].append(te_loss)
    learn_history['test_acc'].append(te_acc)
    lr = optimizer.param_groups[0]['lr']
    learn_history['lr'].append(lr)
#     print('lr = %f' % optimizer.param_groups[0]['lr'])
    scheduler.step(tr_loss)
#     scheduler.step()
#     scheduler.step(tr_loss)
    # 完成一批次训练的结束时间
    now = time.time()
    print('[%3d/%d, %.0f seconds]|\t loss: %f, accuaracy: %2.2f%%\t|\ttest_loss: %f, test_accuaracy: %2.2f%%\ttrain_lr:%.6f'%
          (epoch+1, nepochs, now-since, tr_loss, tr_acc, te_loss, te_acc,lr))
#     print('学习率lr = %f' % lr)
# Out:
# [  1/100, 33 seconds]|	 loss: 2.302325, accuaracy: 12.90%	|	test_loss: 2.302594, test_accuaracy: 9.96%	train_lr:0.010000
# [  2/100, 16 seconds]|	 loss: 2.301883, accuaracy: 12.96%	|	test_loss: 2.302622, test_accuaracy: 9.96%	train_lr:0.010000
# [  3/100, 17 seconds]|	 loss: 2.301255, accuaracy: 13.00%	|	test_loss: 2.302681, test_accuaracy: 9.96%	train_lr:0.010000
# [  4/100, 16 seconds]|	 loss: 2.300531, accuaracy: 12.94%	|	test_loss: 2.302804, test_accuaracy: 9.96%	train_lr:0.010000
# [  5/100, 15 seconds]|	 loss: 2.299764, accuaracy: 13.00%	|	test_loss: 2.302982, test_accuaracy: 9.96%	train_lr:0.010000
# [  6/100, 15 seconds]|	 loss: 2.298731, accuaracy: 13.00%	|	test_loss: 2.303215, test_accuaracy: 9.96%	train_lr:0.010000
# [  7/100, 16 seconds]|	 loss: 2.297634, accuaracy: 13.08%	|	test_loss: 2.303569, test_accuaracy: 9.96%	train_lr:0.010000
# [  8/100, 15 seconds]|	 loss: 2.296629, accuaracy: 12.92%	|	test_loss: 2.304019, test_accuaracy: 9.96%	train_lr:0.010000
# [  9/100, 15 seconds]|	 loss: 2.294764, accuaracy: 13.14%	|	test_loss: 2.304295, test_accuaracy: 9.96%	train_lr:0.010000
# [ 10/100, 15 seconds]|	 loss: 2.291828, accuaracy: 12.94%	|	test_loss: 2.303889, test_accuaracy: 9.96%	train_lr:0.010000
# [ 11/100, 15 seconds]|	 loss: 2.283828, accuaracy: 12.94%	|	test_loss: 2.300860, test_accuaracy: 9.96%	train_lr:0.010000
# [ 12/100, 15 seconds]|	 loss: 2.264476, accuaracy: 13.00%	|	test_loss: 2.292861, test_accuaracy: 9.96%	train_lr:0.010000
# [ 13/100, 15 seconds]|	 loss: 2.240692, accuaracy: 12.94%	|	test_loss: 2.277565, test_accuaracy: 9.96%	train_lr:0.010000
# [ 14/100, 16 seconds]|	 loss: 2.209290, accuaracy: 12.96%	|	test_loss: 2.259166, test_accuaracy: 9.96%	train_lr:0.010000
# [ 15/100, 15 seconds]|	 loss: 2.166503, accuaracy: 13.00%	|	test_loss: 2.236813, test_accuaracy: 9.96%	train_lr:0.010000
# [ 16/100, 15 seconds]|	 loss: 2.130353, accuaracy: 12.98%	|	test_loss: 2.209256, test_accuaracy: 9.96%	train_lr:0.010000
# [ 17/100, 15 seconds]|	 loss: 2.086537, accuaracy: 17.36%	|	test_loss: 2.170263, test_accuaracy: 14.36%	train_lr:0.010000
# [ 18/100, 15 seconds]|	 loss: 2.044422, accuaracy: 19.96%	|	test_loss: 2.134326, test_accuaracy: 17.00%	train_lr:0.010000
# [ 19/100, 17 seconds]|	 loss: 2.047845, accuaracy: 20.04%	|	test_loss: 2.157041, test_accuaracy: 16.85%	train_lr:0.010000
# [ 20/100, 16 seconds]|	 loss: 2.054531, accuaracy: 20.39%	|	test_loss: 2.188582, test_accuaracy: 16.62%	train_lr:0.010000
# [ 21/100, 18 seconds]|	 loss: 1.988721, accuaracy: 22.44%	|	test_loss: 2.105781, test_accuaracy: 17.74%	train_lr:0.010000
# [ 22/100, 17 seconds]|	 loss: 1.989164, accuaracy: 22.79%	|	test_loss: 2.091254, test_accuaracy: 18.05%	train_lr:0.010000
# [ 23/100, 15 seconds]|	 loss: 1.971146, accuaracy: 22.54%	|	test_loss: 2.092195, test_accuaracy: 18.42%	train_lr:0.010000
# [ 24/100, 17 seconds]|	 loss: 2.031825, accuaracy: 25.53%	|	test_loss: 2.119129, test_accuaracy: 19.01%	train_lr:0.010000
# [ 25/100, 16 seconds]|	 loss: 1.934154, accuaracy: 22.83%	|	test_loss: 2.107762, test_accuaracy: 18.61%	train_lr:0.010000
# [ 26/100, 16 seconds]|	 loss: 1.943126, accuaracy: 24.02%	|	test_loss: 2.067922, test_accuaracy: 19.63%	train_lr:0.010000
# [ 27/100, 16 seconds]|	 loss: 1.893273, accuaracy: 24.34%	|	test_loss: 2.069406, test_accuaracy: 19.59%	train_lr:0.010000
# [ 28/100, 16 seconds]|	 loss: 1.878128, accuaracy: 26.90%	|	test_loss: 2.042661, test_accuaracy: 20.80%	train_lr:0.010000
# [ 29/100, 19 seconds]|	 loss: 1.824478, accuaracy: 23.14%	|	test_loss: 2.027469, test_accuaracy: 20.59%	train_lr:0.010000
# [ 30/100, 16 seconds]|	 loss: 1.827560, accuaracy: 29.03%	|	test_loss: 1.996069, test_accuaracy: 22.09%	train_lr:0.010000
# [ 31/100, 16 seconds]|	 loss: 1.857593, accuaracy: 24.47%	|	test_loss: 2.195125, test_accuaracy: 21.69%	train_lr:0.010000
# [ 32/100, 17 seconds]|	 loss: 1.732020, accuaracy: 31.69%	|	test_loss: 1.949435, test_accuaracy: 23.60%	train_lr:0.010000
# [ 33/100, 16 seconds]|	 loss: 1.763284, accuaracy: 29.55%	|	test_loss: 1.979480, test_accuaracy: 23.33%	train_lr:0.010000
# [ 34/100, 16 seconds]|	 loss: 1.674387, accuaracy: 32.64%	|	test_loss: 1.942570, test_accuaracy: 23.44%	train_lr:0.010000
# [ 35/100, 16 seconds]|	 loss: 1.738572, accuaracy: 32.59%	|	test_loss: 2.007145, test_accuaracy: 22.99%	train_lr:0.010000
# [ 36/100, 16 seconds]|	 loss: 1.833887, accuaracy: 25.76%	|	test_loss: 2.136108, test_accuaracy: 19.56%	train_lr:0.010000
# [ 37/100, 16 seconds]|	 loss: 1.714447, accuaracy: 28.73%	|	test_loss: 2.020517, test_accuaracy: 21.67%	train_lr:0.010000
# [ 38/100, 16 seconds]|	 loss: 1.555950, accuaracy: 37.43%	|	test_loss: 2.023543, test_accuaracy: 27.82%	train_lr:0.010000
# [ 39/100, 16 seconds]|	 loss: 1.560925, accuaracy: 36.02%	|	test_loss: 2.092286, test_accuaracy: 26.51%	train_lr:0.010000
# [ 40/100, 16 seconds]|	 loss: 1.578564, accuaracy: 32.21%	|	test_loss: 2.203616, test_accuaracy: 25.80%	train_lr:0.010000
# [ 41/100, 16 seconds]|	 loss: 1.580534, accuaracy: 36.75%	|	test_loss: 2.163438, test_accuaracy: 27.99%	train_lr:0.010000
# [ 42/100, 15 seconds]|	 loss: 1.625112, accuaracy: 35.50%	|	test_loss: 2.234651, test_accuaracy: 24.79%	train_lr:0.010000
# [ 43/100, 15 seconds]|	 loss: 1.526961, accuaracy: 40.52%	|	test_loss: 2.153081, test_accuaracy: 27.31%	train_lr:0.010000
# [ 44/100, 16 seconds]|	 loss: 1.798774, accuaracy: 34.70%	|	test_loss: 2.658947, test_accuaracy: 25.43%	train_lr:0.010000
# [ 45/100, 16 seconds]|	 loss: 1.756744, accuaracy: 36.10%	|	test_loss: 2.342099, test_accuaracy: 23.81%	train_lr:0.010000
# [ 46/100, 15 seconds]|	 loss: 1.401305, accuaracy: 41.58%	|	test_loss: 2.213161, test_accuaracy: 27.99%	train_lr:0.010000
# [ 47/100, 15 seconds]|	 loss: 1.743755, accuaracy: 41.85%	|	test_loss: 2.704094, test_accuaracy: 26.33%	train_lr:0.010000
# [ 48/100, 15 seconds]|	 loss: 1.389810, accuaracy: 46.75%	|	test_loss: 2.240785, test_accuaracy: 29.73%	train_lr:0.010000
# [ 49/100, 16 seconds]|	 loss: 1.549696, accuaracy: 44.45%	|	test_loss: 2.531181, test_accuaracy: 29.02%	train_lr:0.010000
# [ 50/100, 15 seconds]|	 loss: 1.141592, accuaracy: 54.87%	|	test_loss: 2.023862, test_accuaracy: 33.33%	train_lr:0.010000
# [ 51/100, 16 seconds]|	 loss: 1.119089, accuaracy: 56.69%	|	test_loss: 2.139480, test_accuaracy: 31.39%	train_lr:0.010000
# [ 52/100, 16 seconds]|	 loss: 1.404752, accuaracy: 44.57%	|	test_loss: 2.712253, test_accuaracy: 28.87%	train_lr:0.010000
# [ 53/100, 16 seconds]|	 loss: 1.175179, accuaracy: 53.93%	|	test_loss: 2.461458, test_accuaracy: 31.99%	train_lr:0.010000
# [ 54/100, 16 seconds]|	 loss: 1.167501, accuaracy: 57.76%	|	test_loss: 2.496396, test_accuaracy: 29.63%	train_lr:0.010000
# [ 55/100, 16 seconds]|	 loss: 0.958762, accuaracy: 65.15%	|	test_loss: 2.350203, test_accuaracy: 33.12%	train_lr:0.010000
# [ 56/100, 16 seconds]|	 loss: 0.997033, accuaracy: 57.83%	|	test_loss: 2.570302, test_accuaracy: 30.18%	train_lr:0.010000
# [ 57/100, 15 seconds]|	 loss: 1.105339, accuaracy: 58.45%	|	test_loss: 2.595037, test_accuaracy: 30.43%	train_lr:0.010000
# [ 58/100, 16 seconds]|	 loss: 1.928229, accuaracy: 39.64%	|	test_loss: 3.719697, test_accuaracy: 26.17%	train_lr:0.010000
# [ 59/100, 16 seconds]|	 loss: 2.190383, accuaracy: 41.64%	|	test_loss: 3.946517, test_accuaracy: 25.91%	train_lr:0.010000
# [ 60/100, 16 seconds]|	 loss: 1.046979, accuaracy: 60.49%	|	test_loss: 2.480111, test_accuaracy: 32.14%	train_lr:0.010000
# Epoch    61: reducing learning rate of group 0 to 3.0000e-03.
# [ 61/100, 17 seconds]|	 loss: 1.278617, accuaracy: 47.95%	|	test_loss: 2.939584, test_accuaracy: 28.50%	train_lr:0.010000
# [ 62/100, 16 seconds]|	 loss: 0.821090, accuaracy: 71.97%	|	test_loss: 2.301082, test_accuaracy: 32.36%	train_lr:0.003000
# [ 63/100, 16 seconds]|	 loss: 0.683882, accuaracy: 79.22%	|	test_loss: 2.190158, test_accuaracy: 34.82%	train_lr:0.003000
# [ 64/100, 16 seconds]|	 loss: 0.615217, accuaracy: 82.78%	|	test_loss: 2.230802, test_accuaracy: 35.11%	train_lr:0.003000
# [ 65/100, 16 seconds]|	 loss: 0.597986, accuaracy: 82.64%	|	test_loss: 2.301856, test_accuaracy: 34.56%	train_lr:0.003000
# [ 66/100, 16 seconds]|	 loss: 0.571363, accuaracy: 83.64%	|	test_loss: 2.334848, test_accuaracy: 34.36%	train_lr:0.003000
# [ 67/100, 16 seconds]|	 loss: 0.501943, accuaracy: 87.34%	|	test_loss: 2.363097, test_accuaracy: 34.10%	train_lr:0.003000
# [ 68/100, 16 seconds]|	 loss: 0.478554, accuaracy: 87.63%	|	test_loss: 2.398484, test_accuaracy: 35.61%	train_lr:0.003000
# [ 69/100, 16 seconds]|	 loss: 0.462670, accuaracy: 85.55%	|	test_loss: 2.517580, test_accuaracy: 35.11%	train_lr:0.003000
# [ 70/100, 17 seconds]|	 loss: 0.450821, accuaracy: 86.00%	|	test_loss: 2.614301, test_accuaracy: 34.49%	train_lr:0.003000
# [ 71/100, 16 seconds]|	 loss: 0.387492, accuaracy: 90.21%	|	test_loss: 2.674647, test_accuaracy: 35.13%	train_lr:0.003000
# [ 72/100, 16 seconds]|	 loss: 0.364855, accuaracy: 89.62%	|	test_loss: 2.757113, test_accuaracy: 35.25%	train_lr:0.003000
# [ 73/100, 17 seconds]|	 loss: 0.335539, accuaracy: 90.40%	|	test_loss: 2.890922, test_accuaracy: 34.96%	train_lr:0.003000
# [ 74/100, 16 seconds]|	 loss: 0.309102, accuaracy: 92.77%	|	test_loss: 2.950336, test_accuaracy: 34.38%	train_lr:0.003000
# [ 75/100, 16 seconds]|	 loss: 0.318041, accuaracy: 88.60%	|	test_loss: 3.009447, test_accuaracy: 34.21%	train_lr:0.003000
# [ 76/100, 16 seconds]|	 loss: 0.258878, accuaracy: 93.04%	|	test_loss: 3.022047, test_accuaracy: 34.99%	train_lr:0.003000
# [ 77/100, 16 seconds]|	 loss: 0.241155, accuaracy: 93.55%	|	test_loss: 3.121106, test_accuaracy: 34.66%	train_lr:0.003000
# [ 78/100, 16 seconds]|	 loss: 0.237647, accuaracy: 92.85%	|	test_loss: 3.097816, test_accuaracy: 34.42%	train_lr:0.003000
# [ 79/100, 16 seconds]|	 loss: 0.220301, accuaracy: 94.13%	|	test_loss: 3.284713, test_accuaracy: 34.27%	train_lr:0.003000
# [ 80/100, 16 seconds]|	 loss: 0.230277, accuaracy: 92.85%	|	test_loss: 3.405259, test_accuaracy: 34.35%	train_lr:0.003000
# [ 81/100, 16 seconds]|	 loss: 0.200597, accuaracy: 95.60%	|	test_loss: 3.536929, test_accuaracy: 32.30%	train_lr:0.003000
# [ 82/100, 16 seconds]|	 loss: 0.173856, accuaracy: 95.78%	|	test_loss: 3.563819, test_accuaracy: 33.91%	train_lr:0.003000
# [ 83/100, 16 seconds]|	 loss: 0.144859, accuaracy: 97.23%	|	test_loss: 3.512279, test_accuaracy: 34.27%	train_lr:0.003000
# [ 84/100, 16 seconds]|	 loss: 0.162583, accuaracy: 95.56%	|	test_loss: 3.582481, test_accuaracy: 34.97%	train_lr:0.003000
# [ 85/100, 16 seconds]|	 loss: 0.160299, accuaracy: 95.58%	|	test_loss: 3.611986, test_accuaracy: 35.85%	train_lr:0.003000
# [ 86/100, 16 seconds]|	 loss: 0.162034, accuaracy: 95.64%	|	test_loss: 3.753408, test_accuaracy: 34.42%	train_lr:0.003000
# [ 87/100, 16 seconds]|	 loss: 0.200140, accuaracy: 93.43%	|	test_loss: 3.942189, test_accuaracy: 34.41%	train_lr:0.003000
# [ 88/100, 16 seconds]|	 loss: 0.157049, accuaracy: 96.36%	|	test_loss: 3.881562, test_accuaracy: 34.02%	train_lr:0.003000
# [ 89/100, 16 seconds]|	 loss: 0.118915, accuaracy: 97.40%	|	test_loss: 3.848992, test_accuaracy: 35.03%	train_lr:0.003000
# [ 90/100, 16 seconds]|	 loss: 0.142975, accuaracy: 95.31%	|	test_loss: 4.000287, test_accuaracy: 34.82%	train_lr:0.003000
# [ 91/100, 16 seconds]|	 loss: 0.138404, accuaracy: 96.83%	|	test_loss: 4.083781, test_accuaracy: 33.95%	train_lr:0.003000
# [ 92/100, 16 seconds]|	 loss: 0.115710, accuaracy: 97.23%	|	test_loss: 3.989988, test_accuaracy: 34.63%	train_lr:0.003000
# [ 93/100, 16 seconds]|	 loss: 0.131720, accuaracy: 96.42%	|	test_loss: 4.156170, test_accuaracy: 34.86%	train_lr:0.003000
# [ 94/100, 16 seconds]|	 loss: 0.122372, accuaracy: 97.81%	|	test_loss: 4.257496, test_accuaracy: 33.55%	train_lr:0.003000
# [ 95/100, 17 seconds]|	 loss: 0.151624, accuaracy: 95.08%	|	test_loss: 4.379829, test_accuaracy: 34.59%	train_lr:0.003000
# [ 96/100, 15 seconds]|	 loss: 0.144983, accuaracy: 95.84%	|	test_loss: 4.243295, test_accuaracy: 35.62%	train_lr:0.003000
# [ 97/100, 15 seconds]|	 loss: 0.123896, accuaracy: 95.95%	|	test_loss: 4.174740, test_accuaracy: 34.39%	train_lr:0.003000
# [ 98/100, 15 seconds]|	 loss: 0.105705, accuaracy: 96.95%	|	test_loss: 4.251246, test_accuaracy: 35.43%	train_lr:0.003000
# [ 99/100, 17 seconds]|	 loss: 0.107854, accuaracy: 97.03%	|	test_loss: 4.276672, test_accuaracy: 35.79%	train_lr:0.003000
# [100/100, 15 seconds]|	 loss: 0.106268, accuaracy: 96.81%	|	test_loss: 4.477446, test_accuaracy: 34.97%	train_lr:0.003000

# %%
optimizer.param_groups[0]['lr']
# Out:
# 0.003

# %%
nepochs = 200
for epoch in range(100,nepochs):
    # 训练开始时间
    since = time.time()
#     train_epoch(net, criterion, optimizer, train_loader)
    train_epoch(net,criterion,optimizer,train_split_loader[0])
#     scheduler.step(loss, epoch=epoch)
    # 每训练5轮输出一次结果
#     if (epoch)%5 == 0:
    tr_loss, tr_acc = eval(net, criterion, train_split_loader[0])
    te_loss, te_acc = eval(net, criterion, test_loader)
    learn_history['train_loss'].append(tr_loss)
    learn_history['train_acc'].append(tr_acc)
    learn_history['test_loss'].append(te_loss)
    learn_history['test_acc'].append(te_acc)
    lr = optimizer.param_groups[0]['lr']
    learn_history['lr'].append(lr)
#     print('lr = %f' % optimizer.param_groups[0]['lr'])
    scheduler.step(tr_loss)
#     scheduler.step()
#     scheduler.step(tr_loss)
    # 完成一批次训练的结束时间
    now = time.time()
    print('[%3d/%d, %.0f seconds]|\t loss: %f, accuaracy: %2.2f%%\t|\ttest_loss: %f, test_accuaracy: %2.2f%%\ttrain_lr:%.6f'%
          (epoch+1, nepochs, now-since, tr_loss, tr_acc, te_loss, te_acc,lr))
#     print('学习率lr = %f' % lr)
# Out:
# [101/200, 22 seconds]|	 loss: 0.114910, accuaracy: 96.23%	|	test_loss: 4.603034, test_accuaracy: 35.27%	train_lr:0.003000
# [102/200, 15 seconds]|	 loss: 0.116211, accuaracy: 96.77%	|	test_loss: 4.761438, test_accuaracy: 35.10%	train_lr:0.003000
# [103/200, 16 seconds]|	 loss: 0.123826, accuaracy: 96.40%	|	test_loss: 4.608942, test_accuaracy: 34.58%	train_lr:0.003000
# Epoch   104: reducing learning rate of group 0 to 9.0000e-04.
# [104/200, 16 seconds]|	 loss: 0.177667, accuaracy: 94.39%	|	test_loss: 4.656093, test_accuaracy: 34.64%	train_lr:0.003000
# [105/200, 15 seconds]|	 loss: 0.105171, accuaracy: 97.42%	|	test_loss: 4.450865, test_accuaracy: 35.32%	train_lr:0.000900
# [106/200, 17 seconds]|	 loss: 0.068109, accuaracy: 99.00%	|	test_loss: 4.449632, test_accuaracy: 35.32%	train_lr:0.000900
# [107/200, 16 seconds]|	 loss: 0.059305, accuaracy: 98.81%	|	test_loss: 4.463336, test_accuaracy: 34.65%	train_lr:0.000900
# [108/200, 16 seconds]|	 loss: 0.042720, accuaracy: 99.57%	|	test_loss: 4.429978, test_accuaracy: 35.09%	train_lr:0.000900
# [109/200, 16 seconds]|	 loss: 0.044501, accuaracy: 99.39%	|	test_loss: 4.481935, test_accuaracy: 35.82%	train_lr:0.000900
# [110/200, 16 seconds]|	 loss: 0.043030, accuaracy: 99.59%	|	test_loss: 4.422883, test_accuaracy: 35.69%	train_lr:0.000900
# [111/200, 17 seconds]|	 loss: 0.044650, accuaracy: 99.41%	|	test_loss: 4.360134, test_accuaracy: 36.25%	train_lr:0.000900
# [112/200, 16 seconds]|	 loss: 0.046269, accuaracy: 98.59%	|	test_loss: 4.401106, test_accuaracy: 35.56%	train_lr:0.000900
# [113/200, 16 seconds]|	 loss: 0.032253, accuaracy: 100.00%	|	test_loss: 4.402449, test_accuaracy: 35.58%	train_lr:0.000900
# [114/200, 16 seconds]|	 loss: 0.033692, accuaracy: 99.59%	|	test_loss: 4.456348, test_accuaracy: 35.66%	train_lr:0.000900
# [115/200, 16 seconds]|	 loss: 0.031890, accuaracy: 100.00%	|	test_loss: 4.471511, test_accuaracy: 35.86%	train_lr:0.000900
# [116/200, 15 seconds]|	 loss: 0.031735, accuaracy: 99.80%	|	test_loss: 4.560216, test_accuaracy: 35.71%	train_lr:0.000900
# [117/200, 16 seconds]|	 loss: 0.026532, accuaracy: 100.00%	|	test_loss: 4.498571, test_accuaracy: 35.27%	train_lr:0.000900
# [118/200, 16 seconds]|	 loss: 0.025790, accuaracy: 100.00%	|	test_loss: 4.470007, test_accuaracy: 35.36%	train_lr:0.000900
# [119/200, 16 seconds]|	 loss: 0.026296, accuaracy: 99.80%	|	test_loss: 4.508961, test_accuaracy: 35.98%	train_lr:0.000900
# [120/200, 16 seconds]|	 loss: 0.029854, accuaracy: 99.80%	|	test_loss: 4.542139, test_accuaracy: 36.06%	train_lr:0.000900
# [121/200, 16 seconds]|	 loss: 0.021588, accuaracy: 100.00%	|	test_loss: 4.520402, test_accuaracy: 35.53%	train_lr:0.000900
# [122/200, 16 seconds]|	 loss: 0.024693, accuaracy: 100.00%	|	test_loss: 4.563888, test_accuaracy: 36.02%	train_lr:0.000900
# [123/200, 16 seconds]|	 loss: 0.027769, accuaracy: 99.39%	|	test_loss: 4.605667, test_accuaracy: 35.89%	train_lr:0.000900
# [124/200, 17 seconds]|	 loss: 0.020629, accuaracy: 100.00%	|	test_loss: 4.627012, test_accuaracy: 35.31%	train_lr:0.000900
# [125/200, 16 seconds]|	 loss: 0.022978, accuaracy: 99.80%	|	test_loss: 4.607988, test_accuaracy: 35.57%	train_lr:0.000900
# [126/200, 16 seconds]|	 loss: 0.020981, accuaracy: 100.00%	|	test_loss: 4.621037, test_accuaracy: 35.84%	train_lr:0.000900
# [127/200, 16 seconds]|	 loss: 0.020482, accuaracy: 100.00%	|	test_loss: 4.699409, test_accuaracy: 35.61%	train_lr:0.000900
# [128/200, 15 seconds]|	 loss: 0.021317, accuaracy: 100.00%	|	test_loss: 4.631598, test_accuaracy: 36.51%	train_lr:0.000900
# [129/200, 15 seconds]|	 loss: 0.020052, accuaracy: 99.78%	|	test_loss: 4.613418, test_accuaracy: 36.16%	train_lr:0.000900
# [130/200, 16 seconds]|	 loss: 0.019492, accuaracy: 99.80%	|	test_loss: 4.649860, test_accuaracy: 35.84%	train_lr:0.000900
# [131/200, 16 seconds]|	 loss: 0.019894, accuaracy: 99.80%	|	test_loss: 4.615929, test_accuaracy: 36.37%	train_lr:0.000900
# [132/200, 15 seconds]|	 loss: 0.016048, accuaracy: 100.00%	|	test_loss: 4.657794, test_accuaracy: 36.31%	train_lr:0.000900
# [133/200, 15 seconds]|	 loss: 0.021804, accuaracy: 99.78%	|	test_loss: 4.684363, test_accuaracy: 35.76%	train_lr:0.000900
# [134/200, 15 seconds]|	 loss: 0.021010, accuaracy: 99.80%	|	test_loss: 4.620274, test_accuaracy: 36.52%	train_lr:0.000900
# [135/200, 16 seconds]|	 loss: 0.017455, accuaracy: 100.00%	|	test_loss: 4.653231, test_accuaracy: 36.88%	train_lr:0.000900
# [136/200, 14 seconds]|	 loss: 0.018867, accuaracy: 99.61%	|	test_loss: 4.665343, test_accuaracy: 36.08%	train_lr:0.000900
# [137/200, 15 seconds]|	 loss: 0.015507, accuaracy: 100.00%	|	test_loss: 4.592730, test_accuaracy: 36.34%	train_lr:0.000900
# [138/200, 15 seconds]|	 loss: 0.016311, accuaracy: 100.00%	|	test_loss: 4.688294, test_accuaracy: 35.88%	train_lr:0.000900
# [139/200, 15 seconds]|	 loss: 0.015673, accuaracy: 99.80%	|	test_loss: 4.738397, test_accuaracy: 36.33%	train_lr:0.000900
# [140/200, 24 seconds]|	 loss: 0.016589, accuaracy: 99.80%	|	test_loss: 4.737658, test_accuaracy: 36.09%	train_lr:0.000900
# [141/200, 33 seconds]|	 loss: 0.014110, accuaracy: 100.00%	|	test_loss: 4.772289, test_accuaracy: 36.33%	train_lr:0.000900
# [142/200, 32 seconds]|	 loss: 0.015597, accuaracy: 100.00%	|	test_loss: 4.731874, test_accuaracy: 35.71%	train_lr:0.000900
# [143/200, 23 seconds]|	 loss: 0.015911, accuaracy: 100.00%	|	test_loss: 4.730524, test_accuaracy: 36.01%	train_lr:0.000900
# [144/200, 16 seconds]|	 loss: 0.019301, accuaracy: 100.00%	|	test_loss: 4.794385, test_accuaracy: 35.57%	train_lr:0.000900
# [145/200, 15 seconds]|	 loss: 0.017116, accuaracy: 100.00%	|	test_loss: 4.735668, test_accuaracy: 36.21%	train_lr:0.000900
# [146/200, 17 seconds]|	 loss: 0.017309, accuaracy: 99.80%	|	test_loss: 4.774618, test_accuaracy: 36.20%	train_lr:0.000900
# Epoch   147: reducing learning rate of group 0 to 2.7000e-04.
# [147/200, 17 seconds]|	 loss: 0.015920, accuaracy: 99.78%	|	test_loss: 4.804111, test_accuaracy: 35.61%	train_lr:0.000900
# [148/200, 15 seconds]|	 loss: 0.014360, accuaracy: 99.80%	|	test_loss: 4.812763, test_accuaracy: 36.55%	train_lr:0.000270
# [149/200, 15 seconds]|	 loss: 0.012238, accuaracy: 100.00%	|	test_loss: 4.791227, test_accuaracy: 36.12%	train_lr:0.000270
# [150/200, 16 seconds]|	 loss: 0.012840, accuaracy: 100.00%	|	test_loss: 4.810379, test_accuaracy: 35.64%	train_lr:0.000270
# [151/200, 17 seconds]|	 loss: 0.011950, accuaracy: 100.00%	|	test_loss: 4.785299, test_accuaracy: 35.74%	train_lr:0.000270
# [152/200, 15 seconds]|	 loss: 0.013024, accuaracy: 100.00%	|	test_loss: 4.772595, test_accuaracy: 36.19%	train_lr:0.000270
# [153/200, 16 seconds]|	 loss: 0.015369, accuaracy: 99.78%	|	test_loss: 4.783701, test_accuaracy: 36.00%	train_lr:0.000270
# [154/200, 15 seconds]|	 loss: 0.011255, accuaracy: 100.00%	|	test_loss: 4.794255, test_accuaracy: 36.30%	train_lr:0.000270
# [155/200, 15 seconds]|	 loss: 0.013368, accuaracy: 100.00%	|	test_loss: 4.782157, test_accuaracy: 36.14%	train_lr:0.000270
# [156/200, 15 seconds]|	 loss: 0.011983, accuaracy: 100.00%	|	test_loss: 4.756918, test_accuaracy: 35.44%	train_lr:0.000270
# [157/200, 15 seconds]|	 loss: 0.011810, accuaracy: 100.00%	|	test_loss: 4.800139, test_accuaracy: 35.65%	train_lr:0.000270
# [158/200, 15 seconds]|	 loss: 0.011566, accuaracy: 100.00%	|	test_loss: 4.797896, test_accuaracy: 36.12%	train_lr:0.000270
# [159/200, 16 seconds]|	 loss: 0.011495, accuaracy: 100.00%	|	test_loss: 4.775852, test_accuaracy: 36.07%	train_lr:0.000270
# Epoch   160: reducing learning rate of group 0 to 8.1000e-05.
# [160/200, 15 seconds]|	 loss: 0.013035, accuaracy: 100.00%	|	test_loss: 4.802027, test_accuaracy: 35.90%	train_lr:0.000270
# [161/200, 14 seconds]|	 loss: 0.012152, accuaracy: 99.78%	|	test_loss: 4.743396, test_accuaracy: 36.68%	train_lr:0.000081
# [162/200, 14 seconds]|	 loss: 0.012203, accuaracy: 100.00%	|	test_loss: 4.782948, test_accuaracy: 36.10%	train_lr:0.000081
# [163/200, 15 seconds]|	 loss: 0.011313, accuaracy: 100.00%	|	test_loss: 4.788976, test_accuaracy: 36.00%	train_lr:0.000081
# [164/200, 15 seconds]|	 loss: 0.010552, accuaracy: 100.00%	|	test_loss: 4.749664, test_accuaracy: 36.52%	train_lr:0.000081
# [165/200, 14 seconds]|	 loss: 0.012251, accuaracy: 100.00%	|	test_loss: 4.799818, test_accuaracy: 35.99%	train_lr:0.000081
# [166/200, 14 seconds]|	 loss: 0.011495, accuaracy: 100.00%	|	test_loss: 4.828156, test_accuaracy: 35.93%	train_lr:0.000081
# [167/200, 15 seconds]|	 loss: 0.011634, accuaracy: 100.00%	|	test_loss: 4.785566, test_accuaracy: 36.10%	train_lr:0.000081
# [168/200, 14 seconds]|	 loss: 0.011671, accuaracy: 100.00%	|	test_loss: 4.814147, test_accuaracy: 35.95%	train_lr:0.000081
# [169/200, 14 seconds]|	 loss: 0.009635, accuaracy: 100.00%	|	test_loss: 4.816999, test_accuaracy: 35.99%	train_lr:0.000081
# [170/200, 15 seconds]|	 loss: 0.010890, accuaracy: 100.00%	|	test_loss: 4.822970, test_accuaracy: 36.23%	train_lr:0.000081
# [171/200, 14 seconds]|	 loss: 0.010558, accuaracy: 100.00%	|	test_loss: 4.802697, test_accuaracy: 36.05%	train_lr:0.000081
# [172/200, 14 seconds]|	 loss: 0.010481, accuaracy: 100.00%	|	test_loss: 4.808332, test_accuaracy: 36.33%	train_lr:0.000081
# [173/200, 14 seconds]|	 loss: 0.010797, accuaracy: 100.00%	|	test_loss: 4.821884, test_accuaracy: 36.43%	train_lr:0.000081
# [174/200, 15 seconds]|	 loss: 0.009944, accuaracy: 100.00%	|	test_loss: 4.840950, test_accuaracy: 36.16%	train_lr:0.000081
# Epoch   175: reducing learning rate of group 0 to 2.4300e-05.
# [175/200, 15 seconds]|	 loss: 0.011429, accuaracy: 100.00%	|	test_loss: 4.824307, test_accuaracy: 35.92%	train_lr:0.000081
# [176/200, 15 seconds]|	 loss: 0.011696, accuaracy: 100.00%	|	test_loss: 4.802849, test_accuaracy: 35.52%	train_lr:0.000024
# [177/200, 15 seconds]|	 loss: 0.010735, accuaracy: 100.00%	|	test_loss: 4.811613, test_accuaracy: 36.10%	train_lr:0.000024
# [178/200, 15 seconds]|	 loss: 0.011481, accuaracy: 100.00%	|	test_loss: 4.802578, test_accuaracy: 36.23%	train_lr:0.000024
# [179/200, 14 seconds]|	 loss: 0.010738, accuaracy: 100.00%	|	test_loss: 4.781461, test_accuaracy: 35.81%	train_lr:0.000024
# [180/200, 15 seconds]|	 loss: 0.011246, accuaracy: 100.00%	|	test_loss: 4.826907, test_accuaracy: 36.21%	train_lr:0.000024
# Epoch   181: reducing learning rate of group 0 to 7.2900e-06.
# [181/200, 15 seconds]|	 loss: 0.010901, accuaracy: 100.00%	|	test_loss: 4.808518, test_accuaracy: 35.78%	train_lr:0.000024
# [182/200, 15 seconds]|	 loss: 0.011124, accuaracy: 100.00%	|	test_loss: 4.793790, test_accuaracy: 36.08%	train_lr:0.000007
# [183/200, 14 seconds]|	 loss: 0.011001, accuaracy: 100.00%	|	test_loss: 4.824394, test_accuaracy: 36.08%	train_lr:0.000007
# [184/200, 15 seconds]|	 loss: 0.010783, accuaracy: 100.00%	|	test_loss: 4.843285, test_accuaracy: 36.30%	train_lr:0.000007
# [185/200, 15 seconds]|	 loss: 0.010359, accuaracy: 100.00%	|	test_loss: 4.825145, test_accuaracy: 35.87%	train_lr:0.000007
# [186/200, 15 seconds]|	 loss: 0.010430, accuaracy: 100.00%	|	test_loss: 4.841172, test_accuaracy: 35.82%	train_lr:0.000007
# Epoch   187: reducing learning rate of group 0 to 2.1870e-06.
# [187/200, 15 seconds]|	 loss: 0.009810, accuaracy: 100.00%	|	test_loss: 4.815333, test_accuaracy: 36.44%	train_lr:0.000007
# [188/200, 15 seconds]|	 loss: 0.011093, accuaracy: 99.80%	|	test_loss: 4.829150, test_accuaracy: 35.99%	train_lr:0.000002
# [189/200, 15 seconds]|	 loss: 0.011597, accuaracy: 100.00%	|	test_loss: 4.799301, test_accuaracy: 35.89%	train_lr:0.000002
# [190/200, 14 seconds]|	 loss: 0.010860, accuaracy: 100.00%	|	test_loss: 4.815911, test_accuaracy: 36.12%	train_lr:0.000002
# [191/200, 14 seconds]|	 loss: 0.011867, accuaracy: 100.00%	|	test_loss: 4.801054, test_accuaracy: 35.72%	train_lr:0.000002
# [192/200, 14 seconds]|	 loss: 0.010569, accuaracy: 100.00%	|	test_loss: 4.833258, test_accuaracy: 35.29%	train_lr:0.000002
# Epoch   193: reducing learning rate of group 0 to 1.0000e-06.
# [193/200, 14 seconds]|	 loss: 0.010812, accuaracy: 100.00%	|	test_loss: 4.819359, test_accuaracy: 36.11%	train_lr:0.000002
# [194/200, 14 seconds]|	 loss: 0.010573, accuaracy: 100.00%	|	test_loss: 4.833511, test_accuaracy: 35.65%	train_lr:0.000001
# [195/200, 15 seconds]|	 loss: 0.010282, accuaracy: 100.00%	|	test_loss: 4.788193, test_accuaracy: 35.99%	train_lr:0.000001
# [196/200, 15 seconds]|	 loss: 0.009815, accuaracy: 100.00%	|	test_loss: 4.803483, test_accuaracy: 35.64%	train_lr:0.000001
# [197/200, 14 seconds]|	 loss: 0.011595, accuaracy: 100.00%	|	test_loss: 4.826055, test_accuaracy: 35.71%	train_lr:0.000001
# [198/200, 14 seconds]|	 loss: 0.010821, accuaracy: 100.00%	|	test_loss: 4.829529, test_accuaracy: 36.09%	train_lr:0.000001
# [199/200, 14 seconds]|	 loss: 0.010432, accuaracy: 100.00%	|	test_loss: 4.833612, test_accuaracy: 36.08%	train_lr:0.000001
# [200/200, 15 seconds]|	 loss: 0.012105, accuaracy: 100.00%	|	test_loss: 4.815996, test_accuaracy: 35.82%	train_lr:0.000001

# %% [markdown]
# # 保存模型 Save Model

# %%
save_model = False
save_model = True
if save_model:
    state = {
        'net':net.state_dict(),# 模型的参数
        'epoch':nepochs
    }
    os.makedirs('checkpoint',exist_ok=True)
    torch.save(state,'./checkpoint/vgg16_train_split_0.01.ckpt')

# %% [markdown]
# # 测试模型 Test Model

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()
images = images[:4]
labels = labels[:4]
# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))


outputs = net(images.to(device))
_, predicted = torch.max(outputs.cpu(), 1)
print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))

correct = 0
total = 0
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % 
      (100 * correct / total))
# Out:
# GroundTruth:    cat  ship  ship plane
# Predicted:   frog   car   car  ship
# Accuracy of the network on the 10000 test images: 36 %

# %% [markdown]
# # 查看模型在每一个类的准确率

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 51 %
# Accuracy of   car : 46 %
# Accuracy of  bird : 15 %
# Accuracy of   cat : 23 %
# Accuracy of  deer : 25 %
# Accuracy of   dog : 30 %
# Accuracy of  frog : 30 %
# Accuracy of horse : 32 %
# Accuracy of  ship : 43 %
# Accuracy of truck : 43 %

# %% [markdown]
# # 可视化误差曲线，准确率曲线，学习率曲线

# %%
def plot_history(history):
    """
    plot loss and acc history.
    :param history: train returned history object
    """
    epoch_list = range(1,len(history['train_loss'])+1)
    plt.plot(epoch_list, history['train_loss'])
    plt.plot(epoch_list, history['test_loss'])
    plt.xlabel('epoch')
    plt.ylabel('Loss value')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    plt.plot(epoch_list, history['train_acc'])
    plt.plot(epoch_list, history['test_acc'])
    plt.xlabel('epoch')
    plt.ylabel('acc value')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    plt.plot(epoch_list, history['lr'])
    plt.xlabel('epoch')
    plt.ylabel('Train LR')
    plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
plot_history(learn_history)

# %% [markdown]
# # 将数据写入文件

# %%
f = open('history_train_split_0.1.txt','a+')
f.write('new\n')
for i in range(len(learn_history['train_loss'])):
#     print( "%f %f %f %f"% (history['train_loss'][i],history['test_loss'][i],history['train_acc'][i],history['test_acc'][i]))
    f.writelines( "%f %f %f %f %f\n"% (learn_history['train_loss'][i],learn_history['test_loss'][i],learn_history['train_acc'][i],learn_history['test_acc'][i],learn_history['lr'][i]))
f.close()
