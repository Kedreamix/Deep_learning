# %% [markdown]
# # 1.导入所需要的库

# %%
# 导入所需要的库
from __future__ import print_function

import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.optim import lr_scheduler

# %% [markdown]
# # 2.CIFAR10数据集的预处理

# %%
# 超参数
lr = 1e-2
momentum = 0.9
weight_decay = 5e-4
nepochs = 10
Batch_size = 64

# %%
# # 数据增强
# transform = transforms.Compose([
#     transforms.RandomCrop(32, padding=4),  # 数据增广
#     transforms.RandomHorizontalFlip(),  # 数据增广
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),  # 数据归一化
# ])
# # transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],std=[0.2471, 0.2435, 0.2616]),#数据归一化

# %% [markdown]
# # download the CIFAR10 by torchvision, trainset is a torchvision.datasets object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 加载数据集
class CIFAR10Data(object):
    def __init__(self, train_split=0.9):
        train_transform = transforms.Compose([ # 可以串联多个transform函数
            transforms.RandomCrop(size=(32, 32), padding=4),# 随机裁剪图片，即移动
            transforms.RandomHorizontalFlip(), # 随机翻转图片
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],std=[0.2471, 0.2435, 0.2616])
        ])
        
        val_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],std=[0.2471, 0.2435, 0.2616])
        ])
        
        test_transform = val_transform
        # download the CIFAR10 by torchvision, trainset is a torchvision.datasets object
        # transform is performed while obtaining the dataset
        # the ./datas directory is automatically created, and once dowloaded, this code can sense it and will not
        # download it again
        # 简单来说，就是可以在我们的data目录下下载我妈的数据，如果我设置download为True就会自动下载，反之，已经有了可以修改
        train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
        val_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=val_transform)
        test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
        
        # 取得我们的训练集 验证集 测试集
        num_train = len(train_dataset)
        indices = list(range(num_train))
        split = int(num_train * train_split)
        train_idx, val_idx = indices[:split], indices[split:]
        self.train_dataset = torch.utils.data.Subset(train_dataset, train_idx)
        self.val_dataset = torch.utils.data.Subset(val_dataset, val_idx)
        self.test_dataset = test_dataset

    # 利用内置的torch.utils.data.DataLoader从数据集中取出相应batch_size的数据
    # 并且，shuffle = True的意思就是会打乱数据集 ，num_works 就是多线程
    def get_train_loader(self, batch_size=128):
        train_loader = torch.utils.data.DataLoader(
            self.train_dataset, batch_size=batch_size,
            num_workers=2, shuffle=True
        )
        return train_loader

    def get_val_loader(self, batch_size=128):
        val_loader = torch.utils.data.DataLoader(
            self.val_dataset, batch_size=batch_size,
            num_workers=2, shuffle=False
        )
        return val_loader

    def get_test_loader(self, batch_size=128):
        test_loader = torch.utils.data.DataLoader(
            self.test_dataset, batch_size=batch_size,
            num_workers=2, shuffle=False
        )
        return test_loader

# %%
data = CIFAR10Data(train_split=0.8)
train_itr = data.get_train_loader(batch_size=64)
val_itr = data.get_val_loader(batch_size=64)
test_itr = data.get_test_loader(batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# # download the CIFAR10 by torchvision, trainset is a torchvision.datasets object
# # transform is performed while obtaining the dataset
# # the ./dataset directory is automatically created, and once dowloaded, this code can sense it and will not
# # download it again
# train_set = torchvision.datasets.CIFAR10('./data', train=True, 
#                                          download=True, transform=transform)
# test_set = torchvision.datasets.CIFAR10('./data', train=False, 
#                                         download=True, transform=transform)

# train_loader = torch.utils.data.DataLoader(train_set, batch_size=Batch_size, 
#                                            shuffle=True, num_workers=4)
# test_loader = torch.utils.data.DataLoader(test_set, batch_size=Batch_size, 
#                                           shuffle=False, num_workers=4)

# classes = ('plane', 'car', 'bird', 'cat', 'deer',
#            'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# def get_loader(train_set,batch_size=128):
#     loader = torch.utils.data.DataLoader(train_set,batch_size = batch_size,
#                        num_workers=2,shuffle=True)
#     return loader

# %%
# def get_train_split_data( train_set, train_split = 0.8):
#     num_train = len(train_set)
#     indices = list(range(num_train))
#     split = int(num_train * train_split)
#     train_idx, val_idx = indices[:split], indices[split:]
#     train_dataset = torch.utils.data.Subset(train_set,train_idx)
#     val_dataset = torch.utils.data.Subset(val_dataset, val_idx)
#     return train_dataset

# %%
# train_split_loader = []
# train_splits = [0.01,0.1,0.5,0.8,1]
# for train_split in train_splits:
#     train_split_dataset = get_train_split_data(train_set,train_split)
#     train_split_loader.append(get_loader(train_split_dataset,Batch_size))

# %%
# for loader in train_split_loader:
#     print(len(loader))

# %% [markdown]
# # Image displaying

# %%
# Image displaying
import matplotlib.pyplot as plt
import numpy as np

def imshow(img):
    # normalizing
    img = img / 2 + 0.5 # imgs are already noramlized during Transforming in data prepration
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    # plt.show()

image_iter = iter(train_itr)
images, labels = image_iter.next()
imshow(torchvision.utils.make_grid(images[:4]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig = plt.figure(figsize=(25 , 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 10 , idx + 1, xticks =[], yticks = []) # 2 行 10 列
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

plt.show()

# %%
# fig = plt.figure(figsize=(50 , 10))
# imshow(torchvision.utils.make_grid(images[:64]))

# %% [markdown]
# # 测试是否能用GPU

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# # 构建VGG模型

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class VGG(nn.Module):
    
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        self.classifier = nn.Sequential(
            nn.Linear(512,512),
            nn.ReLU(True),
            nn.Dropout(0.2),
            nn.Linear(512,512),
            nn.ReLU(True),
            nn.Dropout(0.2),
            nn.Linear(512,10),
        )
        self.classifier = nn.Linear(512,10)

        self._initialize_weight()
        
    def forward(self, x):
        out = self.features(x)
        # 在进入
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out
    
    # make layers
    def _make_layers(self, cfg):
        layers = []
        in_channels = 3 # RGB 初始通道为3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)] # kernel_size 为 2 x 2,然后步长为2
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1), # 都是(3.3)的卷积核
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]  # RelU
                in_channels = x  # 重定义通道
#         layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)
    
    # 初始化参数
    def _initialize_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # xavier is used in VGG's paper
                nn.init.xavier_normal_(m.weight.data)
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
net = VGG('VGG16').to(device)
print(net)
if device == 'cuda':
    net = nn.DataParallel(net)
    # 当计算图不会改变的时候（每次输入形状相同，模型不改变）的情况下可以提高性能，反之则降低性能
    torch.backends.cudnn.benchmark = True
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
x = torch.randn(2,3,32,32).to(device)
y = net(x)
print(y.shape)
# Out:
# torch.Size([2, 10])

# %% [markdown]
# # Training

# %%
# 定义训练的辅助函数
def eval(model, loss_func, dataloader):
    model.eval()
    loss,accuracy = 0,0
    
    # torch.no_grad不需要计算梯度
    with torch.no_grad():
        for batch_x, batch_y in dataloader:
            batch_x,batch_y = batch_x.to(device), batch_y.to(device)
            outputs = model(batch_x) 
            error = loss_func(outputs,batch_y) # 计算误差
            loss += error.item() 
            
            probs, pred_y = outputs.data.max(dim=1) # 得到概率
            accuracy += (pred_y==batch_y.data).float().sum()/batch_y.size(0) # 准确率
    loss /= len(dataloader)
    accuracy = accuracy*100.0 / len(dataloader)
    return loss, accuracy

def train_epoch(model, loss_func, optimizer, dataloader):
    model.train()
    for batch_x, batch_y in dataloader:
        batch_x,batch_y = batch_x.to(device), batch_y.to(device)
        optimizer.zero_grad() #将参数的grad值初始化为0
        outputs = model(batch_x)
        error = loss_func(outputs, batch_y)
        # 清理内存
        if hasattr(torch.cuda, 'empty_cache'):
            torch.cuda.empty_cache()
        error.backward()  # 反向传播
        # 单次优化
        optimizer.step()

# %%
# # Trainin
# def train(epoch):
#     print('\n Epoch: %d' % (epoch + 1))
#     net.train()
#     train_loss = 0
#     correct = 0
#     total = 0
#     for batch_idx, (inputs, targrts) in enumerate(train_loader):
#         inputs , targrts = inputs.to(device) , targrts.to(device)
        
#         optimizer.zero_grad()
#         outputs = net(inputs)
#         # 得到损失
#         loss= criterion(outputs, targrts)
#         # 清理内存
#         if hasattr(torch.cuda, 'empty_cache'):
#             torch.cuda.empty_cache()

#         # 反向传播
#         loss.backward()
#         # 单次优化
#         optimizer.step()
#         # 得到损失
#         train_loss += loss.item()
#         _, predicted = outputs.max(1)
#         total += targrts.size(0)
#         correct += predicted.eq(targrts).sum().item()
#         if batch_idx % 100 == 99:
#             print('[%d, %5d] loss: %.5f |  Acc:%3f%% (%d/%d)'%
#                  (epoch + 1, batch_idx + 1, train_loss / 2000, 100.*correct/total, correct, total))
#             train_loss = 0.0
#             total = 0
#             correct = 0

# %%
load_history = False
# load_history = True
if load_history:
    learn_history={'train_loss':[],'train_acc':[],'test_loss':[],'test_acc':[],'lr':[]}
    f = open('history.txt','r')
    lines = f.readlines()
    lines.pop(0)
    for line in lines:
        line = line.replace('\n','')
        line = line.split(' ')
        learn_history['train_loss'].append(float(line[0]))
        learn_history['test_loss'].append(float(line[1]))
        learn_history['train_acc'].append(float(line[2]))
        learn_history['test_acc'].append(float(line[3]))
        learn_history['lr'].append(float(line[4]))
    print('load learning history successfully')
else:
    learn_history={'train_loss':[],'train_acc':[],'test_loss':[],'test_acc':[],'lr':[]}

# %%
lr = 1e-2
momentum = 0.9
weight_decay = 5e-4
nepochs = 100
# 定义损失函数为交叉熵损失
criterion = nn.CrossEntropyLoss()
# 优化函数
optimizer = optim.SGD(net.parameters(), lr = lr ,momentum= momentum, weight_decay=weight_decay, nesterov=True)
# optimizer = optim.Adam(net.parameters(),lr = lr,weight_decay=weight_decay)
# scheduler = lr_scheduler.MultiStepLR(optimizer,milestones=[5,10,15] , gamma=0.1 ) # 根据指定的milestones 进行学习率的调整
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5,verbose=True,patience = 5,min_lr = 0.000001) # 动态更新学习率
# scheduler = lr_scheduler.StepLR(optimizer, gamma=0.1 ,step_size = 20) 
# opt = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9, weight_decay=1e-4, nesterov=True)
#   lr_scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size=50, gamma=0.1)

# %%
optimizer = optim.SGD(net.parameters(), lr=1e-1, momentum=0.9, weight_decay=5e-4, nesterov=True)
criterion = nn.CrossEntropyLoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5)

# %%
# # 超参数设置2
# lr = 1e-2
# momentum = 0.9
# weight_decay = 5e-4
# nepochs = 200
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(net.parameters(),lr = lr,weight_decay=weight_decay)
# # 动态更新学习率
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5,verbose=True,patience = 5,min_lr = 0.000001) # 动态更新学习率

# %%
load_model = False
# load_model = True
if load_model:
    checkpoint = torch.load('./checkpoint/vgg.ckpt')
    net.load_state_dict(checkpoint['net'])
    start_epoch = checkpoint['epoch']
else:
    start_epoch = 0
print('start_epoch: %s' % start_epoch)
# Out:
# start_epoch: 0

# %%
# nepochs = 100
# for epoch in range(nepochs):
#     # 训练开始时间
#     since = time.time()
# #     train_epoch(net, criterion, optimizer, train_loader)
#     train_epoch(net,criterion,optimizer,train_split_loader[4])
# #     scheduler.step(loss, epoch=epoch)
#     # 每训练5轮输出一次结果
# #     if (epoch)%5 == 0:
#     tr_loss, tr_acc = eval(net, criterion, train_split_loader[4])
#     te_loss, te_acc = eval(net, criterion, test_loader)
#     learn_history['train_loss'].append(tr_loss)
#     learn_history['train_acc'].append(tr_acc)
#     learn_history['test_loss'].append(te_loss)
#     learn_history['test_acc'].append(te_acc)
#     lr = optimizer.param_groups[0]['lr']
#     learn_history['lr'].append(lr)
# #     print('lr = %f' % optimizer.param_groups[0]['lr'])
#     scheduler.step(tr_loss)
# #     scheduler.step()
# #     scheduler.step(tr_loss)
#     # 完成一批次训练的结束时间
#     now = time.time()
#     print('[%3d/%d, %.0f seconds]|\t loss: %f, accuaracy: %2.2f%%\t|\ttest_loss: %f, test_accuaracy: %2.2f%%\ttrain_lr:%.6f'%
#           (epoch+1, nepochs, now-since, tr_loss, tr_acc, te_loss, te_acc,lr))
# #     print('学习率lr = %f' % lr)

# %%
nepochs = 150
for epoch in range(nepochs):
    # 训练开始时间
    since = time.time()
#     train_epoch(net, criterion, optimizer, train_loader)
#     train_epoch(net,criterion,optimizer,train_split_loader[4])
    train_epoch(net,criterion,optimizer,train_itr)
#     scheduler.step(loss, epoch=epoch)
    # 每训练5轮输出一次结果
#     if (epoch)%5 == 0:
    tr_loss, tr_acc = eval(net, criterion, train_itr)
    te_loss, te_acc = eval(net, criterion, val_itr)
    learn_history['train_loss'].append(tr_loss)
    learn_history['train_acc'].append(tr_acc)
    learn_history['test_loss'].append(te_loss)
    learn_history['test_acc'].append(te_acc)
    lr = optimizer.param_groups[0]['lr']
    learn_history['lr'].append(lr)
#     print('lr = %f' % optimizer.param_groups[0]['lr'])
    scheduler.step(tr_loss)
    scheduler.step(te_acc)
#     scheduler.step()
#     scheduler.step(tr_loss)
    # 完成一批次训练的结束时间
    now = time.time()
    print('[%3d/%d, %.0f seconds]|\t loss: %f, accuaracy: %2.2f%%\t|\tval_loss: %f, test_accuaracy: %2.2f%%\ttrain_lr:%.6f'%
          (epoch+1, nepochs, now-since, tr_loss, tr_acc, te_loss, te_acc,lr))
#     print('学习率lr = %f' % lr)

# te_loss, te_acc = eval(net, criterion, test_itr)
# print('\ttest_loss: %f, test_accuaracy: %2.2f%%\ttrain_lr:%.6f'%( te_loss, te_acc,lr))
# Out:
# [  1/150, 98 seconds]|	 loss: 2.020674, accuaracy: 20.33%	|	val_loss: 2.022274, test_accuaracy: 20.06%	train_lr:0.100000
# [  2/150, 83 seconds]|	 loss: 1.873231, accuaracy: 22.30%	|	val_loss: 1.861430, test_accuaracy: 23.06%	train_lr:0.100000
# [  3/150, 140 seconds]|	 loss: 1.661505, accuaracy: 35.35%	|	val_loss: 1.690567, test_accuaracy: 35.14%	train_lr:0.100000
# [  4/150, 93 seconds]|	 loss: 1.504508, accuaracy: 43.78%	|	val_loss: 1.435480, test_accuaracy: 46.83%	train_lr:0.100000
# [  5/150, 81 seconds]|	 loss: 1.290904, accuaracy: 54.81%	|	val_loss: 1.271929, test_accuaracy: 55.46%	train_lr:0.100000
# [  6/150, 80 seconds]|	 loss: 1.153243, accuaracy: 60.74%	|	val_loss: 1.131981, test_accuaracy: 61.54%	train_lr:0.100000
# [  7/150, 79 seconds]|	 loss: 0.963391, accuaracy: 66.44%	|	val_loss: 0.973627, test_accuaracy: 65.85%	train_lr:0.100000
# [  8/150, 82 seconds]|	 loss: 1.122735, accuaracy: 64.12%	|	val_loss: 1.119476, test_accuaracy: 65.28%	train_lr:0.100000
# [  9/150, 81 seconds]|	 loss: 0.910244, accuaracy: 70.32%	|	val_loss: 0.920762, test_accuaracy: 70.60%	train_lr:0.100000
# [ 10/150, 78 seconds]|	 loss: 0.900553, accuaracy: 69.49%	|	val_loss: 0.904008, test_accuaracy: 69.69%	train_lr:0.100000
# [ 11/150, 80 seconds]|	 loss: 0.842315, accuaracy: 71.08%	|	val_loss: 0.840758, test_accuaracy: 71.29%	train_lr:0.100000
# [ 12/150, 79 seconds]|	 loss: 0.816839, accuaracy: 72.43%	|	val_loss: 0.836830, test_accuaracy: 72.00%	train_lr:0.100000
# [ 13/150, 81 seconds]|	 loss: 0.954756, accuaracy: 69.80%	|	val_loss: 0.964305, test_accuaracy: 70.17%	train_lr:0.100000
# [ 14/150, 80 seconds]|	 loss: 0.881403, accuaracy: 70.62%	|	val_loss: 0.931540, test_accuaracy: 69.75%	train_lr:0.100000
# [ 15/150, 80 seconds]|	 loss: 0.842936, accuaracy: 72.93%	|	val_loss: 0.904660, test_accuaracy: 71.53%	train_lr:0.100000
# [ 16/150, 80 seconds]|	 loss: 0.994795, accuaracy: 68.49%	|	val_loss: 1.013521, test_accuaracy: 68.39%	train_lr:0.100000
# [ 17/150, 79 seconds]|	 loss: 0.757616, accuaracy: 74.65%	|	val_loss: 0.758671, test_accuaracy: 74.48%	train_lr:0.100000
# [ 18/150, 78 seconds]|	 loss: 1.040750, accuaracy: 68.56%	|	val_loss: 1.060198, test_accuaracy: 68.89%	train_lr:0.100000
# [ 19/150, 79 seconds]|	 loss: 0.728659, accuaracy: 75.23%	|	val_loss: 0.758165, test_accuaracy: 74.54%	train_lr:0.100000
# [ 20/150, 80 seconds]|	 loss: 0.692867, accuaracy: 77.11%	|	val_loss: 0.713628, test_accuaracy: 76.39%	train_lr:0.100000
# [ 21/150, 79 seconds]|	 loss: 0.769774, accuaracy: 74.68%	|	val_loss: 0.763363, test_accuaracy: 74.74%	train_lr:0.100000
# [ 22/150, 79 seconds]|	 loss: 0.676382, accuaracy: 76.40%	|	val_loss: 0.703700, test_accuaracy: 76.08%	train_lr:0.100000
# [ 23/150, 79 seconds]|	 loss: 0.581231, accuaracy: 81.22%	|	val_loss: 0.601958, test_accuaracy: 80.58%	train_lr:0.100000
# [ 24/150, 79 seconds]|	 loss: 0.756782, accuaracy: 74.78%	|	val_loss: 0.768670, test_accuaracy: 74.92%	train_lr:0.100000
# [ 25/150, 79 seconds]|	 loss: 0.793859, accuaracy: 73.58%	|	val_loss: 0.774962, test_accuaracy: 74.14%	train_lr:0.100000
# [ 26/150, 78 seconds]|	 loss: 0.947292, accuaracy: 70.50%	|	val_loss: 0.909216, test_accuaracy: 72.00%	train_lr:0.100000
# [ 27/150, 79 seconds]|	 loss: 0.602436, accuaracy: 79.93%	|	val_loss: 0.607422, test_accuaracy: 79.70%	train_lr:0.100000
# [ 28/150, 80 seconds]|	 loss: 0.584334, accuaracy: 80.85%	|	val_loss: 0.626834, test_accuaracy: 79.86%	train_lr:0.100000
# [ 29/150, 79 seconds]|	 loss: 0.461031, accuaracy: 84.84%	|	val_loss: 0.509666, test_accuaracy: 83.44%	train_lr:0.050000
# [ 30/150, 79 seconds]|	 loss: 0.422043, accuaracy: 86.06%	|	val_loss: 0.483334, test_accuaracy: 83.99%	train_lr:0.050000
# [ 31/150, 80 seconds]|	 loss: 0.545212, accuaracy: 81.19%	|	val_loss: 0.592909, test_accuaracy: 80.02%	train_lr:0.050000
# [ 32/150, 79 seconds]|	 loss: 0.417993, accuaracy: 86.04%	|	val_loss: 0.462320, test_accuaracy: 84.24%	train_lr:0.050000
# [ 33/150, 79 seconds]|	 loss: 0.475529, accuaracy: 84.13%	|	val_loss: 0.530694, test_accuaracy: 82.60%	train_lr:0.050000
# [ 34/150, 79 seconds]|	 loss: 0.543551, accuaracy: 82.36%	|	val_loss: 0.600891, test_accuaracy: 80.33%	train_lr:0.050000
# [ 35/150, 79 seconds]|	 loss: 0.457667, accuaracy: 84.69%	|	val_loss: 0.514708, test_accuaracy: 82.66%	train_lr:0.050000
# [ 36/150, 80 seconds]|	 loss: 0.467702, accuaracy: 84.58%	|	val_loss: 0.517067, test_accuaracy: 82.69%	train_lr:0.050000
# [ 37/150, 80 seconds]|	 loss: 0.497349, accuaracy: 83.54%	|	val_loss: 0.536219, test_accuaracy: 82.73%	train_lr:0.050000
# [ 38/150, 79 seconds]|	 loss: 0.246057, accuaracy: 92.01%	|	val_loss: 0.347886, test_accuaracy: 88.34%	train_lr:0.025000
# [ 39/150, 82 seconds]|	 loss: 0.288926, accuaracy: 90.45%	|	val_loss: 0.402396, test_accuaracy: 86.39%	train_lr:0.025000
# [ 40/150, 86 seconds]|	 loss: 0.313178, accuaracy: 89.44%	|	val_loss: 0.454669, test_accuaracy: 85.15%	train_lr:0.025000
# [ 41/150, 84 seconds]|	 loss: 0.270580, accuaracy: 90.74%	|	val_loss: 0.410552, test_accuaracy: 86.16%	train_lr:0.025000
# [ 42/150, 95 seconds]|	 loss: 0.264767, accuaracy: 91.35%	|	val_loss: 0.385202, test_accuaracy: 87.55%	train_lr:0.025000
# [ 43/150, 90 seconds]|	 loss: 0.279670, accuaracy: 90.60%	|	val_loss: 0.409640, test_accuaracy: 86.32%	train_lr:0.025000
# [ 44/150, 96 seconds]|	 loss: 0.180681, accuaracy: 93.92%	|	val_loss: 0.331841, test_accuaracy: 88.99%	train_lr:0.012500
# [ 45/150, 91 seconds]|	 loss: 0.166563, accuaracy: 94.42%	|	val_loss: 0.343399, test_accuaracy: 89.06%	train_lr:0.012500
# [ 46/150, 91 seconds]|	 loss: 0.163568, accuaracy: 94.47%	|	val_loss: 0.362405, test_accuaracy: 88.73%	train_lr:0.012500
# [ 47/150, 95 seconds]|	 loss: 0.202212, accuaracy: 93.21%	|	val_loss: 0.410460, test_accuaracy: 87.42%	train_lr:0.012500
# [ 48/150, 90 seconds]|	 loss: 0.159114, accuaracy: 94.57%	|	val_loss: 0.350381, test_accuaracy: 88.90%	train_lr:0.012500
# [ 49/150, 94 seconds]|	 loss: 0.214149, accuaracy: 92.89%	|	val_loss: 0.416107, test_accuaracy: 87.56%	train_lr:0.012500
# [ 50/150, 90 seconds]|	 loss: 0.152928, accuaracy: 94.82%	|	val_loss: 0.349773, test_accuaracy: 89.22%	train_lr:0.012500
# [ 51/150, 96 seconds]|	 loss: 0.142467, accuaracy: 95.13%	|	val_loss: 0.345534, test_accuaracy: 89.17%	train_lr:0.012500
# [ 52/150, 92 seconds]|	 loss: 0.163903, accuaracy: 94.48%	|	val_loss: 0.355915, test_accuaracy: 89.24%	train_lr:0.012500
# [ 53/150, 90 seconds]|	 loss: 0.158533, accuaracy: 94.45%	|	val_loss: 0.366860, test_accuaracy: 88.12%	train_lr:0.012500
# [ 54/150, 88 seconds]|	 loss: 0.157486, accuaracy: 94.48%	|	val_loss: 0.368476, test_accuaracy: 88.56%	train_lr:0.012500
# [ 55/150, 97 seconds]|	 loss: 0.155446, accuaracy: 94.72%	|	val_loss: 0.354947, test_accuaracy: 88.97%	train_lr:0.012500
# [ 56/150, 90 seconds]|	 loss: 0.149677, accuaracy: 94.97%	|	val_loss: 0.364638, test_accuaracy: 88.61%	train_lr:0.012500
# [ 57/150, 96 seconds]|	 loss: 0.073674, accuaracy: 97.53%	|	val_loss: 0.309953, test_accuaracy: 90.71%	train_lr:0.006250
# [ 58/150, 91 seconds]|	 loss: 0.083016, accuaracy: 97.18%	|	val_loss: 0.337461, test_accuaracy: 90.17%	train_lr:0.006250
# [ 59/150, 95 seconds]|	 loss: 0.068012, accuaracy: 97.67%	|	val_loss: 0.330745, test_accuaracy: 90.41%	train_lr:0.006250
# [ 60/150, 87 seconds]|	 loss: 0.074099, accuaracy: 97.37%	|	val_loss: 0.362763, test_accuaracy: 90.08%	train_lr:0.006250
# [ 61/150, 84 seconds]|	 loss: 0.068207, accuaracy: 97.67%	|	val_loss: 0.345464, test_accuaracy: 90.56%	train_lr:0.006250
# [ 62/150, 86 seconds]|	 loss: 0.068943, accuaracy: 97.70%	|	val_loss: 0.334416, test_accuaracy: 90.47%	train_lr:0.006250
# [ 63/150, 82 seconds]|	 loss: 0.072650, accuaracy: 97.61%	|	val_loss: 0.349788, test_accuaracy: 90.30%	train_lr:0.006250
# [ 64/150, 82 seconds]|	 loss: 0.086618, accuaracy: 96.94%	|	val_loss: 0.370761, test_accuaracy: 89.74%	train_lr:0.006250
# [ 65/150, 90 seconds]|	 loss: 0.024291, accuaracy: 99.26%	|	val_loss: 0.300842, test_accuaracy: 91.81%	train_lr:0.003125
# [ 66/150, 86 seconds]|	 loss: 0.022778, accuaracy: 99.29%	|	val_loss: 0.305486, test_accuaracy: 91.88%	train_lr:0.003125
# [ 67/150, 87 seconds]|	 loss: 0.022039, accuaracy: 99.24%	|	val_loss: 0.327149, test_accuaracy: 91.79%	train_lr:0.003125
# [ 68/150, 83 seconds]|	 loss: 0.032100, accuaracy: 98.90%	|	val_loss: 0.357505, test_accuaracy: 91.07%	train_lr:0.003125
# [ 69/150, 80 seconds]|	 loss: 0.022644, accuaracy: 99.24%	|	val_loss: 0.343222, test_accuaracy: 91.34%	train_lr:0.003125
# [ 70/150, 84 seconds]|	 loss: 0.015956, accuaracy: 99.49%	|	val_loss: 0.338310, test_accuaracy: 91.86%	train_lr:0.003125
# [ 71/150, 90 seconds]|	 loss: 0.019826, accuaracy: 99.36%	|	val_loss: 0.351398, test_accuaracy: 91.72%	train_lr:0.003125
# [ 72/150, 85 seconds]|	 loss: 0.019661, accuaracy: 99.36%	|	val_loss: 0.358472, test_accuaracy: 91.55%	train_lr:0.003125
# [ 73/150, 83 seconds]|	 loss: 0.017364, accuaracy: 99.47%	|	val_loss: 0.344932, test_accuaracy: 91.59%	train_lr:0.003125
# [ 74/150, 89 seconds]|	 loss: 0.017129, accuaracy: 99.47%	|	val_loss: 0.364577, test_accuaracy: 91.40%	train_lr:0.003125
# [ 75/150, 82 seconds]|	 loss: 0.016910, accuaracy: 99.44%	|	val_loss: 0.342584, test_accuaracy: 91.60%	train_lr:0.003125
# [ 76/150, 81 seconds]|	 loss: 0.009360, accuaracy: 99.70%	|	val_loss: 0.332083, test_accuaracy: 91.97%	train_lr:0.001563
# [ 77/150, 82 seconds]|	 loss: 0.006583, accuaracy: 99.82%	|	val_loss: 0.319515, test_accuaracy: 92.39%	train_lr:0.001563
# [ 78/150, 87 seconds]|	 loss: 0.005593, accuaracy: 99.86%	|	val_loss: 0.330373, test_accuaracy: 92.66%	train_lr:0.001563
# [ 79/150, 82 seconds]|	 loss: 0.005393, accuaracy: 99.88%	|	val_loss: 0.327906, test_accuaracy: 92.71%	train_lr:0.001563
# [ 80/150, 86 seconds]|	 loss: 0.005426, accuaracy: 99.85%	|	val_loss: 0.340249, test_accuaracy: 92.36%	train_lr:0.001563
# [ 81/150, 81 seconds]|	 loss: 0.006086, accuaracy: 99.83%	|	val_loss: 0.350005, test_accuaracy: 92.40%	train_lr:0.001563
# [ 82/150, 81 seconds]|	 loss: 0.005325, accuaracy: 99.87%	|	val_loss: 0.351349, test_accuaracy: 92.39%	train_lr:0.001563
# [ 83/150, 82 seconds]|	 loss: 0.006646, accuaracy: 99.82%	|	val_loss: 0.358659, test_accuaracy: 92.20%	train_lr:0.001563
# [ 84/150, 81 seconds]|	 loss: 0.005702, accuaracy: 99.84%	|	val_loss: 0.356153, test_accuaracy: 92.23%	train_lr:0.001563
# [ 85/150, 84 seconds]|	 loss: 0.005071, accuaracy: 99.85%	|	val_loss: 0.346839, test_accuaracy: 92.22%	train_lr:0.001563
# [ 86/150, 85 seconds]|	 loss: 0.005207, accuaracy: 99.85%	|	val_loss: 0.354130, test_accuaracy: 92.08%	train_lr:0.001563
# [ 87/150, 83 seconds]|	 loss: 0.005182, accuaracy: 99.87%	|	val_loss: 0.348978, test_accuaracy: 92.42%	train_lr:0.001563
# [ 88/150, 92 seconds]|	 loss: 0.005361, accuaracy: 99.85%	|	val_loss: 0.345229, test_accuaracy: 92.53%	train_lr:0.001563
# [ 89/150, 85 seconds]|	 loss: 0.004494, accuaracy: 99.87%	|	val_loss: 0.357948, test_accuaracy: 92.30%	train_lr:0.001563
# [ 90/150, 85 seconds]|	 loss: 0.003601, accuaracy: 99.91%	|	val_loss: 0.363256, test_accuaracy: 92.05%	train_lr:0.001563
# [ 91/150, 83 seconds]|	 loss: 0.004305, accuaracy: 99.88%	|	val_loss: 0.367417, test_accuaracy: 92.06%	train_lr:0.001563
# [ 92/150, 85 seconds]|	 loss: 0.005374, accuaracy: 99.85%	|	val_loss: 0.363304, test_accuaracy: 92.24%	train_lr:0.001563
# [ 93/150, 92 seconds]|	 loss: 0.005960, accuaracy: 99.85%	|	val_loss: 0.369794, test_accuaracy: 92.49%	train_lr:0.001563
# [ 94/150, 85 seconds]|	 loss: 0.005041, accuaracy: 99.87%	|	val_loss: 0.361340, test_accuaracy: 92.35%	train_lr:0.001563
# [ 95/150, 83 seconds]|	 loss: 0.005197, accuaracy: 99.86%	|	val_loss: 0.367195, test_accuaracy: 92.28%	train_lr:0.001563
# [ 96/150, 84 seconds]|	 loss: 0.003005, accuaracy: 99.94%	|	val_loss: 0.351936, test_accuaracy: 92.60%	train_lr:0.000781
# [ 97/150, 84 seconds]|	 loss: 0.002863, accuaracy: 99.93%	|	val_loss: 0.347703, test_accuaracy: 92.62%	train_lr:0.000781
# [ 98/150, 85 seconds]|	 loss: 0.002464, accuaracy: 99.96%	|	val_loss: 0.352191, test_accuaracy: 92.83%	train_lr:0.000781
# [ 99/150, 93 seconds]|	 loss: 0.002527, accuaracy: 99.93%	|	val_loss: 0.349668, test_accuaracy: 92.71%	train_lr:0.000781
# [100/150, 90 seconds]|	 loss: 0.002148, accuaracy: 99.96%	|	val_loss: 0.349668, test_accuaracy: 92.63%	train_lr:0.000781
# [101/150, 88 seconds]|	 loss: 0.001967, accuaracy: 99.97%	|	val_loss: 0.348832, test_accuaracy: 92.71%	train_lr:0.000781
# [102/150, 86 seconds]|	 loss: 0.002081, accuaracy: 99.96%	|	val_loss: 0.350750, test_accuaracy: 92.75%	train_lr:0.000781
# [103/150, 84 seconds]|	 loss: 0.001672, accuaracy: 99.97%	|	val_loss: 0.344624, test_accuaracy: 92.86%	train_lr:0.000781
# [104/150, 87 seconds]|	 loss: 0.002450, accuaracy: 99.95%	|	val_loss: 0.348577, test_accuaracy: 92.74%	train_lr:0.000781
# [105/150, 81 seconds]|	 loss: 0.002491, accuaracy: 99.95%	|	val_loss: 0.352119, test_accuaracy: 92.80%	train_lr:0.000781
# [106/150, 88 seconds]|	 loss: 0.002511, accuaracy: 99.94%	|	val_loss: 0.353078, test_accuaracy: 92.74%	train_lr:0.000781
# [107/150, 83 seconds]|	 loss: 0.002065, accuaracy: 99.96%	|	val_loss: 0.350266, test_accuaracy: 92.84%	train_lr:0.000781
# [108/150, 82 seconds]|	 loss: 0.002099, accuaracy: 99.95%	|	val_loss: 0.359709, test_accuaracy: 92.71%	train_lr:0.000781
# [109/150, 82 seconds]|	 loss: 0.001328, accuaracy: 99.99%	|	val_loss: 0.346730, test_accuaracy: 92.90%	train_lr:0.000391
# [110/150, 82 seconds]|	 loss: 0.001528, accuaracy: 99.97%	|	val_loss: 0.349255, test_accuaracy: 92.78%	train_lr:0.000391
# [111/150, 81 seconds]|	 loss: 0.001484, accuaracy: 99.99%	|	val_loss: 0.351899, test_accuaracy: 92.73%	train_lr:0.000391
# [112/150, 88 seconds]|	 loss: 0.001242, accuaracy: 99.99%	|	val_loss: 0.350636, test_accuaracy: 92.89%	train_lr:0.000391
# [113/150, 87 seconds]|	 loss: 0.001138, accuaracy: 99.99%	|	val_loss: 0.352435, test_accuaracy: 92.81%	train_lr:0.000391
# [114/150, 82 seconds]|	 loss: 0.001363, accuaracy: 99.99%	|	val_loss: 0.353800, test_accuaracy: 92.83%	train_lr:0.000391
# [115/150, 82 seconds]|	 loss: 0.001305, accuaracy: 99.99%	|	val_loss: 0.351896, test_accuaracy: 92.74%	train_lr:0.000391
# [116/150, 81 seconds]|	 loss: 0.001294, accuaracy: 99.98%	|	val_loss: 0.348238, test_accuaracy: 92.90%	train_lr:0.000391
# [117/150, 82 seconds]|	 loss: 0.001078, accuaracy: 99.99%	|	val_loss: 0.349916, test_accuaracy: 92.94%	train_lr:0.000391
# [118/150, 82 seconds]|	 loss: 0.001405, accuaracy: 99.99%	|	val_loss: 0.350293, test_accuaracy: 92.93%	train_lr:0.000391
# [119/150, 82 seconds]|	 loss: 0.001169, accuaracy: 99.99%	|	val_loss: 0.349696, test_accuaracy: 92.98%	train_lr:0.000391
# [120/150, 82 seconds]|	 loss: 0.001538, accuaracy: 99.98%	|	val_loss: 0.353165, test_accuaracy: 92.94%	train_lr:0.000391
# [121/150, 83 seconds]|	 loss: 0.001173, accuaracy: 99.99%	|	val_loss: 0.351451, test_accuaracy: 92.82%	train_lr:0.000391
# [122/150, 88 seconds]|	 loss: 0.001172, accuaracy: 99.99%	|	val_loss: 0.350818, test_accuaracy: 92.89%	train_lr:0.000391
# [123/150, 87 seconds]|	 loss: 0.001142, accuaracy: 99.99%	|	val_loss: 0.353915, test_accuaracy: 92.78%	train_lr:0.000195
# [124/150, 89 seconds]|	 loss: 0.000985, accuaracy: 99.99%	|	val_loss: 0.350826, test_accuaracy: 92.98%	train_lr:0.000195
# [125/150, 90 seconds]|	 loss: 0.000985, accuaracy: 99.99%	|	val_loss: 0.353102, test_accuaracy: 92.80%	train_lr:0.000195
# [126/150, 89 seconds]|	 loss: 0.001016, accuaracy: 99.99%	|	val_loss: 0.351363, test_accuaracy: 92.95%	train_lr:0.000195
# [127/150, 88 seconds]|	 loss: 0.001086, accuaracy: 99.99%	|	val_loss: 0.352085, test_accuaracy: 92.92%	train_lr:0.000195
# [128/150, 86 seconds]|	 loss: 0.001053, accuaracy: 99.99%	|	val_loss: 0.350380, test_accuaracy: 92.85%	train_lr:0.000195
# [129/150, 90 seconds]|	 loss: 0.001178, accuaracy: 99.99%	|	val_loss: 0.352403, test_accuaracy: 92.85%	train_lr:0.000195
# [130/150, 85 seconds]|	 loss: 0.001155, accuaracy: 99.99%	|	val_loss: 0.350150, test_accuaracy: 92.78%	train_lr:0.000098
# [131/150, 90 seconds]|	 loss: 0.000942, accuaracy: 99.99%	|	val_loss: 0.349356, test_accuaracy: 92.86%	train_lr:0.000098
# [132/150, 86 seconds]|	 loss: 0.001139, accuaracy: 99.99%	|	val_loss: 0.348046, test_accuaracy: 92.94%	train_lr:0.000098
# [133/150, 88 seconds]|	 loss: 0.001029, accuaracy: 99.99%	|	val_loss: 0.347616, test_accuaracy: 92.93%	train_lr:0.000098
# [134/150, 84 seconds]|	 loss: 0.001024, accuaracy: 99.99%	|	val_loss: 0.347339, test_accuaracy: 92.86%	train_lr:0.000098
# [135/150, 93 seconds]|	 loss: 0.000925, accuaracy: 99.99%	|	val_loss: 0.349834, test_accuaracy: 92.96%	train_lr:0.000098
# [136/150, 90 seconds]|	 loss: 0.000857, accuaracy: 100.00%	|	val_loss: 0.349846, test_accuaracy: 92.91%	train_lr:0.000098
# [137/150, 86 seconds]|	 loss: 0.000872, accuaracy: 100.00%	|	val_loss: 0.349078, test_accuaracy: 92.87%	train_lr:0.000098
# [138/150, 85 seconds]|	 loss: 0.001134, accuaracy: 99.99%	|	val_loss: 0.347699, test_accuaracy: 92.91%	train_lr:0.000098
# [139/150, 90 seconds]|	 loss: 0.001143, accuaracy: 99.99%	|	val_loss: 0.347508, test_accuaracy: 92.80%	train_lr:0.000098
# [140/150, 88 seconds]|	 loss: 0.001047, accuaracy: 99.99%	|	val_loss: 0.349718, test_accuaracy: 92.88%	train_lr:0.000098
# [141/150, 82 seconds]|	 loss: 0.000937, accuaracy: 99.99%	|	val_loss: 0.345394, test_accuaracy: 93.00%	train_lr:0.000098
# [142/150, 83 seconds]|	 loss: 0.000951, accuaracy: 99.99%	|	val_loss: 0.346610, test_accuaracy: 92.96%	train_lr:0.000049
# [143/150, 85 seconds]|	 loss: 0.000968, accuaracy: 99.99%	|	val_loss: 0.349575, test_accuaracy: 92.84%	train_lr:0.000049
# [144/150, 85 seconds]|	 loss: 0.001019, accuaracy: 99.99%	|	val_loss: 0.346775, test_accuaracy: 92.90%	train_lr:0.000049
# [145/150, 91 seconds]|	 loss: 0.000880, accuaracy: 100.00%	|	val_loss: 0.348139, test_accuaracy: 92.91%	train_lr:0.000049
# [146/150, 85 seconds]|	 loss: 0.000950, accuaracy: 99.99%	|	val_loss: 0.346292, test_accuaracy: 92.97%	train_lr:0.000049
# [147/150, 82 seconds]|	 loss: 0.000880, accuaracy: 100.00%	|	val_loss: 0.348941, test_accuaracy: 92.92%	train_lr:0.000049
# [148/150, 81 seconds]|	 loss: 0.000870, accuaracy: 100.00%	|	val_loss: 0.347032, test_accuaracy: 93.01%	train_lr:0.000024
# [149/150, 82 seconds]|	 loss: 0.000966, accuaracy: 99.99%	|	val_loss: 0.348563, test_accuaracy: 92.92%	train_lr:0.000024
# [150/150, 81 seconds]|	 loss: 0.000962, accuaracy: 99.99%	|	val_loss: 0.347297, test_accuaracy: 92.86%	train_lr:0.000024

# %%
optimizer.param_groups[0]['lr']
# Out:
# 2.44140625e-05

# %% [markdown]
# # 保存模型 Save Model

# %%
save_model = False
save_model = True
if save_model:
    state = {
        'net':net.state_dict(),# 模型的参数
        'epoch':nepochs
    }
    os.makedirs('checkpoint',exist_ok=True)
    torch.save(state,'./checkpoint/vgg16_train_improve_acc2.ckpt')

# %% [markdown]
# # 测试模型 Test Model

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
dataiter = iter(train_itr)
images, labels = dataiter.next()
images = images[:4]
labels = labels[:4]
# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))


outputs = net(images.to(device))
_, predicted = torch.max(outputs.cpu(), 1)
print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))

correct = 0
total = 0
with torch.no_grad():
    for data in test_itr:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %.2f %%' % 
      (100 * correct / total))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# GroundTruth:    car  bird plane   car
# Predicted:    car  bird plane   car
# Accuracy of the network on the 10000 test images: 92.58 %

# %% [markdown]
# # 查看模型在每一个类的准确率

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in test_itr:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2.2f %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 98.21 %
# Accuracy of   car : 96.00 %
# Accuracy of  bird : 88.61 %
# Accuracy of   cat : 87.67 %
# Accuracy of  deer : 90.91 %
# Accuracy of   dog : 89.83 %
# Accuracy of  frog : 92.86 %
# Accuracy of horse : 98.44 %
# Accuracy of  ship : 98.28 %
# Accuracy of truck : 93.59 %

# %% [markdown]
# # 可视化误差曲线，准确率曲线，学习率曲线

# %%
import matplotlib.pyplot as plt
def plot_history(history):
    """
    plot loss and acc history.
    :param history: train returned history object
    """
    epoch_list = range(1,len(history['train_loss'])+1)
    plt.plot(epoch_list, history['train_loss'])
    plt.plot(epoch_list, history['test_loss'])
    plt.xlabel('epoch')
    plt.ylabel('Loss value')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    plt.plot(epoch_list, history['train_acc'])
    plt.plot(epoch_list, history['test_acc'])
    plt.xlabel('epoch')
    plt.ylabel('acc value')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    plt.plot(epoch_list, history['lr'])
    plt.xlabel('epoch')
    plt.ylabel('Train LR')
    plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
plot_history(learn_history)

# %% [markdown]
# # 将数据写入文件

# %%
f = open('history_train_split_improve.txt','a+')
f.write('new\n')
for i in range(len(learn_history['train_loss'])):
#     print( "%f %f %f %f"% (history['train_loss'][i],history['test_loss'][i],history['train_acc'][i],history['test_acc'][i]))
    f.writelines( "%f %f %f %f %f\n"% (learn_history['train_loss'][i],learn_history['test_loss'][i],learn_history['train_acc'][i],learn_history['test_acc'][i],learn_history['lr'][i]))
f.close()

# %%
f = open('history_train_split_improve.txt','a+')
f.write('new\n')
for i in range(len(learn_history['train_loss'])):
#     print( "%f %f %f %f"% (history['train_loss'][i],history['test_loss'][i],history['train_acc'][i],history['test_acc'][i]))
    f.writelines( "%f %f %f %f %f\n"% (learn_history['train_loss'][i],learn_history['test_loss'][i],learn_history['train_acc'][i],learn_history['test_acc'][i],learn_history['lr'][i]))
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-567c49c2a23a> in <module>
#       1 f = open('history_train_split_improve.txt','a+')
#       2 f.write('new\n')
# ----> 3 for i in range(len(learn_history['train_loss'])):
#       4 #     print( "%f %f %f %f"% (history['train_loss'][i],history['test_loss'][i],history['train_acc'][i],history['test_acc'][i]))
#       5     f.writelines( "%f %f %f %f %f %f %f\n"% (learn_history['train_loss'][i],learn_history['test_loss'][i],learn_history['train_acc'][i],learn_history['test_acc'][i],learn_history['lr'][i],learn_history['val_loss'][i],learn_history['val_acc']))
#
# NameError: name 'learn_history' is not defined
